# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.multiclass import OneVsOneClassifier
# Import packages to visualize the classifer
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
import warnings
import numpy as np
import cv2



from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels



# carrega dataset
dados = pd.read_csv('file.csv', sep=';')
#nova seleção
dados.pop("HU0").values
dados.pop("HU1").values
dados.pop("HU2").values
dados.pop("HU3").values
dados.pop("HU4").values
dados.pop("XMIN").values
dados.pop("YMIN").values
dados.pop("XMAX").values
dados.pop("YMAX").values
dados.pop("DEDOS").values
dados.head(5)
# Out:
#    CX   CY  RAIOMIN  AREACIRCMIN  RAIOMAX  AREACIRCMAX  HU5  HU6 Classe
# 0  94  113       85       533.80       29       182.12    5    6      A
# 1  94  113       85       533.80       29       182.12    4    6      A
# 2  95  113       86       540.08       30       188.40    5    6      A
# 3  96  113       85       533.80       30       188.40    5    6      A
# 4  97  113       84       527.52       30       188.40   -5    6      A

# %%
# y = carrega classes
y=dados.pop('Classe').values

######################Normalizando aqui########################################################
# x = carrega as instâncias
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
X=scaler.fit_transform(dados.values)
#X= dados.values

# biblioteca para validação cruzada
from sklearn.model_selection import KFold
from sklearn.ensemble.forest import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.naive_bayes import GaussianNB

# Numero de folds para cros validation
kf = KFold(n_splits=6, shuffle=True)


classificador_arvores = DecisionTreeClassifier(random_state=0)

classificador_KNN = KNeighborsClassifier(n_neighbors=3)

classificador_naive = GaussianNB()
list_knn=[]
list_arvores=[]
list_naive=[]

#svm simples
#svm = SVC(C=1000, cache_size=250, class_weight=None, coef0=0.0,decision_function_shape='ovr', degree=3, gamma="scale", kernel='rbf', max_iter=-1, probability=False, random_state=None, shrinking=True, tol=0.001, verbose=False)

'''
esse é o svm one vs one
svm = OneVsOneClassifier(SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
    decision_function_shape='ovr', degree=3, gamma="scale", kernel='rbf',
    max_iter=-1, probability=False, random_state=None, shrinking=True,
    tol=0.001, verbose=False))
'''


from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit

#shuffle embaralha os folds
cv = ShuffleSplit(n_splits=3, test_size=0.3, random_state=0)

#cross_val_score faz o cross validation de forma mais automatica
#scores_arvores= cross_val_score(classificador_arvores, X, y, cv=cv)
scores_knn= cross_val_score(classificador_KNN, X, y, cv=cv)
#scores_naive= cross_val_score(classificador_naive, X, y, cv=cv)
#scores_svm= cross_val_score(svm, X, y, cv=cv)



#print("Accuracy arvores: %0.2f (+/- %0.2f)" % (scores_arvores.mean(), scores_arvores.std() *2))
print("Accuracy knn: %0.2f (+/- %0.2f)" % (scores_knn.mean(), scores_knn.std() *2))
#print("Accuracy naive: %0.2f (+/- %0.2f)" % (scores_naive.mean(), scores_naive.std() *2))
#print("Accuracy svm: %0.2f (+/- %0.2f)" % (scores_svm.mean(), scores_svm.std() *2))

#Para mais informações pesquise no google :)
# Out:
# Accuracy knn: 0.89 (+/- 0.02)
